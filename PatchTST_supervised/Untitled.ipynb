# %%
pwd
# Out:
# '/gemini/code/PatchTST/PatchTST_supervised'

# %%
# !pip list
# Out:
# Package                        Version
# ------------------------------ --------------------
# absl-py                        2.1.0
# accelerate                     0.26.1
# addict                         2.4.0
# aenum                          3.1.15
# aiofiles                       23.2.1
# aiohttp                        3.9.1
# aiosignal                      1.3.1
# albumentations                 1.3.1
# altair                         5.2.0
# annotated-types                0.6.0
# antlr4-python3-runtime         4.9.3
# anyio                          4.2.0
# anykeystore                    0.2
# apex                           0.9.10.dev0
# appdirs                        1.4.4
# archspec                       0.2.1
# argon2-cffi                    23.1.0
# argon2-cffi-bindings           21.2.0
# arrow                          1.3.0
# astor                          0.8.1
# asttokens                      2.4.1
# astunparse                     1.6.3
# ...

# %%
! sh ./scripts/PatchTST/weather.sh
# Out:
# Traceback (most recent call last):
#   File "run_longExp.py", line 4, in <module>
#     from exp.exp_main import Exp_Main
#   File "/gemini/code/PatchTST/PatchTST_supervised/exp/exp_main.py", line 1, in <module>
#     from data_provider.data_factory import data_provider
#   File "/gemini/code/PatchTST/PatchTST_supervised/data_provider/data_factory.py", line 1, in <module>
#     from data_provider.data_loader import Dataset_ETT_hour, Dataset_ETT_minute, Dataset_Custom, Dataset_Pred
#   File "/gemini/code/PatchTST/PatchTST_supervised/data_provider/data_loader.py", line 8, in <module>
#     from utils.timefeatures import time_features
# ModuleNotFoundError: No module named 'utils.timefeatures'
# Traceback (most recent call last):
#   File "run_longExp.py", line 4, in <module>
#     from exp.exp_main import Exp_Main
#   File "/gemini/code/PatchTST/PatchTST_supervised/exp/exp_main.py", line 1, in <module>
#     from data_provider.data_factory import data_provider
# ...

# %%
import pandas as pd 
pd.read
